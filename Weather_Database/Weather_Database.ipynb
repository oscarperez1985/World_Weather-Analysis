# %% [markdown]
# ## Deliverable 1: Retrieve Weather Data
# ### Deliverable 1 Instructions
# Generate a set of 2,000 random latitudes and longitudes, retrieve the nearest city, and perform an API call with the OpenWeatherMap. In addition to the city weather data you gathered in this module, use your API skills to retrieve the current weather description for each city. Then, create a new DataFrame containing the updated weather data.

# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import requests
from citipy import citipy
import time
from datetime import datetime
import sys

# %%
# Import API Key
sys.path.insert(0, 'C:/Users/oscar/OneDrive/Data Analytics Bootcamp/Misc/')
from config import kopenweather as api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lats_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lats_lngs)
   
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
        
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 761

# %%
# Get weather information for every city in the list:

# Setup base URL for API Call.
base_url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + api_key

# Create an empty city list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = base_url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather["weather"][0]["description"]
        city_country = city_weather["sys"]["country"]
        
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 2 of Set 1 | hobart
# Processing Record 3 of Set 1 | qinzhou
# Processing Record 4 of Set 1 | ponta do sol
# Processing Record 5 of Set 1 | busselton
# Processing Record 6 of Set 1 | saldanha
# Processing Record 7 of Set 1 | el alto
# Processing Record 8 of Set 1 | ayan
# Processing Record 9 of Set 1 | bluff
# Processing Record 10 of Set 1 | kapaa
# Processing Record 11 of Set 1 | cabo san lucas
# Processing Record 12 of Set 1 | la ronge
# Processing Record 13 of Set 1 | chokurdakh
# Processing Record 14 of Set 1 | fort-shevchenko
# Processing Record 15 of Set 1 | tuatapere
# Processing Record 16 of Set 1 | longyearbyen
# Processing Record 17 of Set 1 | nabire
# Processing Record 18 of Set 1 | sumbuya
# Processing Record 19 of Set 1 | avarua
# Processing Record 20 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 21 of Set 1 | vestmannaeyjar
# Processing Record 22 of Set 1 | tasiilaq
# Processing Record 23 of Set 1 | torbay
# Processing Record 24 of Set 1 | airai
# Processing Record 25 of Set 1 | mahebourg
# Processing Record 26 of Set 1 | yellowknife
# Processing Record 27 of Set 1 | arraial do cabo
# Processing Record 28 of Set 1 | hermanus
# Processing Record 29 of Set 1 | iranshahr
# Processing Record 30 of Set 1 | mataura
# Processing Record 31 of Set 1 | bethel
# Processing Record 32 of Set 1 | parati
# Processing Record 33 of Set 1 | viedma
# Processing Record 34 of Set 1 | rikitea
# Processing Record 35 of Set 1 | kichmengskiy gorodok
# Processing Record 36 of Set 1 | daxian
# City not found. Skipping...
# Processing Record 37 of Set 1 | muros
# Processing Record 38 of Set 1 | san quintin
# Processing Record 39 of Set 1 | port alfred
# Processing Record 40 of Set 1 | hithadhoo
# Processing Record 41 of Set 1 | teguldet
# Processing Record 42 of Set 1 | sao desiderio
# Processing Record 43 of Set 1 | upernavik
# Processing Record 44 of Set 1 | bemidji
# Processing Record 45 of Set 1 | carnarvon
# Processing Record 46 of Set 1 | kaitangata
# Processing Record 47 of Set 1 | lavrentiya
# Processing Record 48 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 49 of Set 1 | assare
# Processing Record 50 of Set 1 | ronnede
# Processing Record 1 of Set 2 | teeli
# City not found. Skipping...
# Processing Record 2 of Set 2 | barrow
# City not found. Skipping...
# Processing Record 3 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 4 of Set 2 | ilulissat
# Processing Record 5 of Set 2 | qaanaaq
# Processing Record 6 of Set 2 | ho
# City not found. Skipping...
# Processing Record 7 of Set 2 | tigil
# Processing Record 8 of Set 2 | macaubas
# Processing Record 9 of Set 2 | kirkuk
# Processing Record 10 of Set 2 | punta arenas
# Processing Record 11 of Set 2 | severo-kurilsk
# Processing Record 12 of Set 2 | miyazu
# Processing Record 13 of Set 2 | tilichiki
# Processing Record 14 of Set 2 | puerto ayora
# Processing Record 15 of Set 2 | butaritari
# Processing Record 16 of Set 2 | tarnos
# Processing Record 17 of Set 2 | srednekolymsk
# Processing Record 18 of Set 2 | kattivakkam
# Processing Record 19 of Set 2 | tenenkou
# Processing Record 20 of Set 2 | mar del plata
# Processing Record 21 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 22 of Set 2 | kruisfontein
# Processing Record 23 of Set 2 | zapolyarnyy
# Processing Record 24 of Set 2 | noumea
# Processing Record 25 of Set 2 | hilo
# Processing Record 26 of Set 2 | ankang
# Processing Record 27 of Set 2 | isiro
# Processing Record 28 of Set 2 | tiksi
# Processing Record 29 of Set 2 | vaini
# Processing Record 30 of Set 2 | tuktoyaktuk
# Processing Record 31 of Set 2 | cap malheureux
# Processing Record 32 of Set 2 | georgetown
# Processing Record 33 of Set 2 | mersing
# Processing Record 34 of Set 2 | narsaq
# Processing Record 35 of Set 2 | lebu
# Processing Record 36 of Set 2 | castro
# Processing Record 37 of Set 2 | akyab
# Processing Record 38 of Set 2 | pevek
# Processing Record 39 of Set 2 | jardim
# Processing Record 40 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 41 of Set 2 | cherskiy
# Processing Record 42 of Set 2 | tessalit
# Processing Record 43 of Set 2 | faanui
# Processing Record 44 of Set 2 | knysna
# Processing Record 45 of Set 2 | tevaitoa
# Processing Record 46 of Set 2 | bengkulu
# Processing Record 47 of Set 2 | diego de almagro
# Processing Record 48 of Set 2 | saint-philippe
# Processing Record 49 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 50 of Set 2 | buenavista
# Processing Record 1 of Set 3 | sorong
# Processing Record 2 of Set 3 | juneau
# Processing Record 3 of Set 3 | jand
# Processing Record 4 of Set 3 | kavieng
# Processing Record 5 of Set 3 | new norfolk
# Processing Record 6 of Set 3 | aksarka
# Processing Record 7 of Set 3 | sitka
# Processing Record 8 of Set 3 | tapiramuta
# Processing Record 9 of Set 3 | victoria
# Processing Record 10 of Set 3 | salalah
# Processing Record 11 of Set 3 | kudahuvadhoo
# Processing Record 12 of Set 3 | idritsa
# Processing Record 13 of Set 3 | bredasdorp
# Processing Record 14 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 15 of Set 3 | saint george
# Processing Record 16 of Set 3 | khovu-aksy
# Processing Record 17 of Set 3 | ostersund
# Processing Record 18 of Set 3 | itapirapua
# Processing Record 19 of Set 3 | te anau
# Processing Record 20 of Set 3 | beloha
# Processing Record 21 of Set 3 | mrirt
# City not found. Skipping...
# Processing Record 22 of Set 3 | mount gambier
# Processing Record 23 of Set 3 | bilibino
# Processing Record 24 of Set 3 | ibra
# Processing Record 25 of Set 3 | henties bay
# Processing Record 26 of Set 3 | kodiak
# Processing Record 27 of Set 3 | port lincoln
# Processing Record 28 of Set 3 | atuona
# Processing Record 29 of Set 3 | cordoba
# Processing Record 30 of Set 3 | miraflores
# Processing Record 31 of Set 3 | letlhakane
# Processing Record 32 of Set 3 | banda aceh
# Processing Record 33 of Set 3 | murray bridge
# Processing Record 34 of Set 3 | vila velha
# Processing Record 35 of Set 3 | saskylakh
# Processing Record 36 of Set 3 | nyurba
# Processing Record 37 of Set 3 | qasigiannguit
# Processing Record 38 of Set 3 | albany
# Processing Record 39 of Set 3 | coahuayana
# Processing Record 40 of Set 3 | lucea
# Processing Record 41 of Set 3 | ribeira grande
# Processing Record 42 of Set 3 | east london
# Processing Record 43 of Set 3 | cape town
# Processing Record 44 of Set 3 | balezino
# Processing Record 45 of Set 3 | vanimo
# Processing Record 46 of Set 3 | guerrero negro
# Processing Record 47 of Set 3 | kemin
# Processing Record 48 of Set 3 | taoudenni
# Processing Record 49 of Set 3 | dikson
# Processing Record 50 of Set 3 | nanortalik
# Processing Record 1 of Set 4 | ushuaia
# Processing Record 2 of Set 4 | peniche
# Processing Record 3 of Set 4 | sur
# Processing Record 4 of Set 4 | salinopolis
# Processing Record 5 of Set 4 | poum
# Processing Record 6 of Set 4 | carbonia
# Processing Record 7 of Set 4 | hualmay
# Processing Record 8 of Set 4 | cullman
# Processing Record 9 of Set 4 | frunze
# Processing Record 10 of Set 4 | tabarqah
# City not found. Skipping...
# Processing Record 11 of Set 4 | halvad
# Processing Record 12 of Set 4 | luruaco
# Processing Record 13 of Set 4 | norman wells
# Processing Record 14 of Set 4 | yurga
# Processing Record 15 of Set 4 | sao filipe
# Processing Record 16 of Set 4 | nakusp
# Processing Record 17 of Set 4 | san pedro
# Processing Record 18 of Set 4 | ahipara
# Processing Record 19 of Set 4 | shar
# Processing Record 20 of Set 4 | kenai
# Processing Record 21 of Set 4 | bauchi
# Processing Record 22 of Set 4 | toliary
# City not found. Skipping...
# Processing Record 23 of Set 4 | kieta
# Processing Record 24 of Set 4 | phra phutthabat
# Processing Record 25 of Set 4 | jamestown
# Processing Record 26 of Set 4 | sahbuz
# Processing Record 27 of Set 4 | clyde river
# Processing Record 28 of Set 4 | macara
# Processing Record 29 of Set 4 | usinsk
# Processing Record 30 of Set 4 | gimli
# Processing Record 31 of Set 4 | moerai
# Processing Record 32 of Set 4 | arlit
# Processing Record 33 of Set 4 | lompoc
# Processing Record 34 of Set 4 | klaksvik
# Processing Record 35 of Set 4 | luderitz
# Processing Record 36 of Set 4 | vredendal
# Processing Record 37 of Set 4 | poso
# Processing Record 38 of Set 4 | lexington
# Processing Record 39 of Set 4 | thompson
# Processing Record 40 of Set 4 | mahon
# Processing Record 41 of Set 4 | kathmandu
# Processing Record 42 of Set 4 | dunedin
# Processing Record 43 of Set 4 | naryan-mar
# Processing Record 44 of Set 4 | tarazona
# Processing Record 45 of Set 4 | liepaja
# Processing Record 46 of Set 4 | vila franca do campo
# Processing Record 47 of Set 4 | chitral
# Processing Record 48 of Set 4 | rawson
# Processing Record 49 of Set 4 | khatanga
# Processing Record 50 of Set 4 | grand-santi
# Processing Record 1 of Set 5 | haslett
# Processing Record 2 of Set 5 | ajdabiya
# Processing Record 3 of Set 5 | amurzet
# Processing Record 4 of Set 5 | whitianga
# Processing Record 5 of Set 5 | lazarev
# Processing Record 6 of Set 5 | kuhestan
# City not found. Skipping...
# Processing Record 7 of Set 5 | teixoso
# Processing Record 8 of Set 5 | anadyr
# Processing Record 9 of Set 5 | souillac
# Processing Record 10 of Set 5 | port elizabeth
# Processing Record 11 of Set 5 | olafsvik
# Processing Record 12 of Set 5 | kungurtug
# Processing Record 13 of Set 5 | kazalinsk
# City not found. Skipping...
# Processing Record 14 of Set 5 | moyale
# Processing Record 15 of Set 5 | chuy
# Processing Record 16 of Set 5 | yulara
# Processing Record 17 of Set 5 | escanaba
# Processing Record 18 of Set 5 | babanusah
# City not found. Skipping...
# Processing Record 19 of Set 5 | cockburn harbour
# City not found. Skipping...
# Processing Record 20 of Set 5 | naze
# Processing Record 21 of Set 5 | umzimvubu
# City not found. Skipping...
# Processing Record 22 of Set 5 | kearney
# Processing Record 23 of Set 5 | homer
# Processing Record 24 of Set 5 | chernyshevskiy
# Processing Record 25 of Set 5 | talnakh
# Processing Record 26 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 27 of Set 5 | aflu
# City not found. Skipping...
# Processing Record 28 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 29 of Set 5 | elko
# Processing Record 30 of Set 5 | aktash
# Processing Record 31 of Set 5 | campbell river
# Processing Record 32 of Set 5 | winnemucca
# Processing Record 33 of Set 5 | derzhavinsk
# Processing Record 34 of Set 5 | broken hill
# Processing Record 35 of Set 5 | ballitoville
# Processing Record 36 of Set 5 | komatipoort
# Processing Record 37 of Set 5 | hobyo
# Processing Record 38 of Set 5 | okhotsk
# Processing Record 39 of Set 5 | palabuhanratu
# City not found. Skipping...
# Processing Record 40 of Set 5 | richards bay
# Processing Record 41 of Set 5 | perivolia
# Processing Record 42 of Set 5 | acari
# Processing Record 43 of Set 5 | avallon
# Processing Record 44 of Set 5 | beldanga
# Processing Record 45 of Set 5 | safaga
# Processing Record 46 of Set 5 | baruun-urt
# Processing Record 47 of Set 5 | oistins
# Processing Record 48 of Set 5 | samfya
# Processing Record 49 of Set 5 | anandpur sahib
# Processing Record 50 of Set 5 | mandal
# Processing Record 1 of Set 6 | chegem
# Processing Record 2 of Set 6 | pocone
# Processing Record 3 of Set 6 | itoman
# Processing Record 4 of Set 6 | cayenne
# Processing Record 5 of Set 6 | amarante do maranhao
# Processing Record 6 of Set 6 | salym
# Processing Record 7 of Set 6 | kununurra
# Processing Record 8 of Set 6 | natal
# Processing Record 9 of Set 6 | mubi
# Processing Record 10 of Set 6 | nipawin
# Processing Record 11 of Set 6 | totness
# Processing Record 12 of Set 6 | floro
# Processing Record 13 of Set 6 | hami
# Processing Record 14 of Set 6 | dosso
# Processing Record 15 of Set 6 | pechora
# Processing Record 16 of Set 6 | etchoropo
# Processing Record 17 of Set 6 | hofn
# Processing Record 18 of Set 6 | lac-megantic
# Processing Record 19 of Set 6 | chapais
# Processing Record 20 of Set 6 | bathsheba
# Processing Record 21 of Set 6 | preobrazheniye
# Processing Record 22 of Set 6 | aykhal
# Processing Record 23 of Set 6 | barra do garcas
# Processing Record 24 of Set 6 | bonfim
# Processing Record 25 of Set 6 | calahorra
# Processing Record 26 of Set 6 | tigre
# Processing Record 27 of Set 6 | san juan ixcoy
# Processing Record 28 of Set 6 | marzuq
# Processing Record 29 of Set 6 | yurimaguas
# Processing Record 30 of Set 6 | ypsonas
# Processing Record 31 of Set 6 | esperance
# Processing Record 32 of Set 6 | acapulco
# Processing Record 33 of Set 6 | port macquarie
# Processing Record 34 of Set 6 | necochea
# Processing Record 35 of Set 6 | parana
# Processing Record 36 of Set 6 | kirakira
# Processing Record 37 of Set 6 | saint andrews
# Processing Record 38 of Set 6 | nemuro
# Processing Record 39 of Set 6 | dali
# Processing Record 40 of Set 6 | nikolskoye
# Processing Record 41 of Set 6 | vardo
# Processing Record 42 of Set 6 | tottenham
# Processing Record 43 of Set 6 | gangarampur
# Processing Record 44 of Set 6 | krasnoselkup
# Processing Record 45 of Set 6 | copiapo
# Processing Record 46 of Set 6 | saint-louis
# Processing Record 47 of Set 6 | bambous virieux
# Processing Record 48 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 49 of Set 6 | los llanos de aridane
# Processing Record 50 of Set 6 | marquette
# Processing Record 1 of Set 7 | pacific grove
# Processing Record 2 of Set 7 | sinnamary
# Processing Record 3 of Set 7 | sakakah
# Processing Record 4 of Set 7 | ambilobe
# Processing Record 5 of Set 7 | upata
# Processing Record 6 of Set 7 | mezen
# Processing Record 7 of Set 7 | fortuna
# Processing Record 8 of Set 7 | ambulu
# Processing Record 9 of Set 7 | borogontsy
# Processing Record 10 of Set 7 | corum
# Processing Record 11 of Set 7 | podolinec
# Processing Record 12 of Set 7 | oyama
# Processing Record 13 of Set 7 | faratsiho
# Processing Record 14 of Set 7 | higuey
# City not found. Skipping...
# Processing Record 15 of Set 7 | latina
# Processing Record 16 of Set 7 | evensk
# Processing Record 17 of Set 7 | omboue
# Processing Record 18 of Set 7 | ust-tsilma
# Processing Record 19 of Set 7 | albi
# Processing Record 20 of Set 7 | blonduos
# City not found. Skipping...
# Processing Record 21 of Set 7 | petropavlovsk-kamchatskiy
# Processing Record 22 of Set 7 | acajutla
# Processing Record 23 of Set 7 | amapa
# Processing Record 24 of Set 7 | khandyga
# Processing Record 25 of Set 7 | kunming
# Processing Record 26 of Set 7 | nsanje
# Processing Record 27 of Set 7 | erenhot
# Processing Record 28 of Set 7 | sentyabrskiy
# City not found. Skipping...
# Processing Record 29 of Set 7 | pochutla
# Processing Record 30 of Set 7 | leshukonskoye
# Processing Record 31 of Set 7 | jutai
# Processing Record 32 of Set 7 | abalak
# Processing Record 33 of Set 7 | kharp
# Processing Record 34 of Set 7 | tucuma
# Processing Record 35 of Set 7 | dwarka
# Processing Record 36 of Set 7 | coxim
# Processing Record 37 of Set 7 | christchurch
# Processing Record 38 of Set 7 | strangnas
# Processing Record 39 of Set 7 | ubinskoye
# Processing Record 40 of Set 7 | hokitika
# Processing Record 41 of Set 7 | urumqi
# Processing Record 42 of Set 7 | mogok
# Processing Record 43 of Set 7 | tahta
# Processing Record 44 of Set 7 | ponca city
# Processing Record 45 of Set 7 | nantucket
# Processing Record 46 of Set 7 | amiens
# Processing Record 47 of Set 7 | challans
# Processing Record 48 of Set 7 | hasaki
# Processing Record 49 of Set 7 | kahului
# Processing Record 50 of Set 7 | hasilpur
# Processing Record 1 of Set 8 | jiexiu
# Processing Record 2 of Set 8 | sorvag
# City not found. Skipping...
# Processing Record 3 of Set 8 | axim
# Processing Record 4 of Set 8 | makakilo city
# Processing Record 5 of Set 8 | provideniya
# Processing Record 6 of Set 8 | semirara
# Processing Record 7 of Set 8 | port augusta
# Processing Record 8 of Set 8 | redmond
# Processing Record 9 of Set 8 | oranjemund
# Processing Record 10 of Set 8 | zunyi
# Processing Record 11 of Set 8 | fallon
# Processing Record 12 of Set 8 | owando
# Processing Record 13 of Set 8 | portland
# Processing Record 14 of Set 8 | langham
# Processing Record 15 of Set 8 | ucluelet
# Processing Record 16 of Set 8 | kajaani
# Processing Record 17 of Set 8 | kothi
# Processing Record 18 of Set 8 | el retorno
# Processing Record 19 of Set 8 | hay river
# Processing Record 20 of Set 8 | czluchow
# Processing Record 21 of Set 8 | meyungs
# City not found. Skipping...
# Processing Record 22 of Set 8 | krasnooktyabrskiy
# Processing Record 23 of Set 8 | baykit
# Processing Record 24 of Set 8 | ust-nera
# Processing Record 25 of Set 8 | pingliang
# Processing Record 26 of Set 8 | sioux lookout
# Processing Record 27 of Set 8 | mgachi
# Processing Record 28 of Set 8 | haines junction
# Processing Record 29 of Set 8 | marathon
# Processing Record 30 of Set 8 | xuddur
# Processing Record 31 of Set 8 | nara
# Processing Record 32 of Set 8 | elbrus
# Processing Record 33 of Set 8 | amboasary
# Processing Record 34 of Set 8 | venice
# Processing Record 35 of Set 8 | bousse
# Processing Record 36 of Set 8 | hella
# Processing Record 37 of Set 8 | boende
# Processing Record 38 of Set 8 | alamosa
# Processing Record 39 of Set 8 | puerto escondido
# Processing Record 40 of Set 8 | najran
# Processing Record 41 of Set 8 | butembo
# Processing Record 42 of Set 8 | xuanzhou
# Processing Record 43 of Set 8 | camacha
# Processing Record 44 of Set 8 | nioro
# Processing Record 45 of Set 8 | nishihara
# Processing Record 46 of Set 8 | tabuk
# Processing Record 47 of Set 8 | parabel
# Processing Record 48 of Set 8 | marsa matruh
# Processing Record 49 of Set 8 | kaniama
# Processing Record 50 of Set 8 | cockburn town
# Processing Record 1 of Set 9 | along
# Processing Record 2 of Set 9 | green river
# Processing Record 3 of Set 9 | ostrovnoy
# Processing Record 4 of Set 9 | pisco
# Processing Record 5 of Set 9 | coquimbo
# Processing Record 6 of Set 9 | nova londrina
# Processing Record 7 of Set 9 | constitucion
# Processing Record 8 of Set 9 | khonuu
# City not found. Skipping...
# Processing Record 9 of Set 9 | castelldefels
# Processing Record 10 of Set 9 | san patricio
# Processing Record 11 of Set 9 | uyuni
# Processing Record 12 of Set 9 | sydney mines
# Processing Record 13 of Set 9 | lazaro cardenas
# Processing Record 14 of Set 9 | abha
# Processing Record 15 of Set 9 | port hedland
# Processing Record 16 of Set 9 | saint-gedeon
# Processing Record 17 of Set 9 | tonantins
# Processing Record 18 of Set 9 | meulaboh
# Processing Record 19 of Set 9 | todos santos
# Processing Record 20 of Set 9 | decatur
# Processing Record 21 of Set 9 | kamenskoye
# City not found. Skipping...
# Processing Record 22 of Set 9 | araouane
# Processing Record 23 of Set 9 | saint joseph
# Processing Record 24 of Set 9 | flinders
# Processing Record 25 of Set 9 | ixtapa
# Processing Record 26 of Set 9 | solovetskiy
# City not found. Skipping...
# Processing Record 27 of Set 9 | byron bay
# Processing Record 28 of Set 9 | zhigansk
# Processing Record 29 of Set 9 | katobu
# Processing Record 30 of Set 9 | tabiauea
# City not found. Skipping...
# Processing Record 31 of Set 9 | senneterre
# Processing Record 32 of Set 9 | nueve de julio
# Processing Record 33 of Set 9 | dingle
# Processing Record 34 of Set 9 | datong
# Processing Record 35 of Set 9 | ust-uda
# Processing Record 36 of Set 9 | mao
# Processing Record 37 of Set 9 | maghama
# City not found. Skipping...
# Processing Record 38 of Set 9 | saint-francois
# Processing Record 39 of Set 9 | pokhara
# Processing Record 40 of Set 9 | taywarah
# Processing Record 41 of Set 9 | stornoway
# Processing Record 42 of Set 9 | auki
# Processing Record 43 of Set 9 | amderma
# City not found. Skipping...
# Processing Record 44 of Set 9 | port hardy
# Processing Record 45 of Set 9 | mount isa
# Processing Record 46 of Set 9 | skjervoy
# Processing Record 47 of Set 9 | taltal
# Processing Record 48 of Set 9 | concarneau
# Processing Record 49 of Set 9 | iqaluit
# Processing Record 50 of Set 9 | adrar
# Processing Record 1 of Set 10 | lorengau
# Processing Record 2 of Set 10 | snezhnogorsk
# Processing Record 3 of Set 10 | itarema
# Processing Record 4 of Set 10 | manakara
# Processing Record 5 of Set 10 | novoye leushino
# Processing Record 6 of Set 10 | bolkhov
# Processing Record 7 of Set 10 | kimbe
# Processing Record 8 of Set 10 | amahai
# Processing Record 9 of Set 10 | warqla
# City not found. Skipping...
# Processing Record 10 of Set 10 | kahone
# Processing Record 11 of Set 10 | thinadhoo
# Processing Record 12 of Set 10 | broome
# Processing Record 13 of Set 10 | popondetta
# Processing Record 14 of Set 10 | tamandare
# Processing Record 15 of Set 10 | alexandria
# Processing Record 16 of Set 10 | eldikan
# City not found. Skipping...
# Processing Record 17 of Set 10 | pasni
# Processing Record 18 of Set 10 | tynda
# Processing Record 19 of Set 10 | katsuura
# Processing Record 20 of Set 10 | udachnyy
# Processing Record 21 of Set 10 | roald
# Processing Record 22 of Set 10 | eureka
# Processing Record 23 of Set 10 | saint-augustin
# Processing Record 24 of Set 10 | nieuw amsterdam
# Processing Record 25 of Set 10 | rincon
# Processing Record 26 of Set 10 | balimo
# City not found. Skipping...
# Processing Record 27 of Set 10 | aasiaat
# Processing Record 28 of Set 10 | lashio
# Processing Record 29 of Set 10 | coihaique
# Processing Record 30 of Set 10 | taburi
# City not found. Skipping...
# Processing Record 31 of Set 10 | taua
# Processing Record 32 of Set 10 | pascagoula
# Processing Record 33 of Set 10 | nizhneyansk
# City not found. Skipping...
# Processing Record 34 of Set 10 | chara
# Processing Record 35 of Set 10 | college
# Processing Record 36 of Set 10 | kant
# Processing Record 37 of Set 10 | ketchikan
# Processing Record 38 of Set 10 | praya
# Processing Record 39 of Set 10 | poya
# Processing Record 40 of Set 10 | kerema
# Processing Record 41 of Set 10 | waingapu
# Processing Record 42 of Set 10 | corozal
# Processing Record 43 of Set 10 | sorland
# Processing Record 44 of Set 10 | galesong
# Processing Record 45 of Set 10 | angoche
# Processing Record 46 of Set 10 | asau
# Processing Record 47 of Set 10 | pangnirtung
# Processing Record 48 of Set 10 | vostok
# Processing Record 49 of Set 10 | pedernales
# Processing Record 50 of Set 10 | alta floresta
# Processing Record 1 of Set 11 | jiuquan
# Processing Record 2 of Set 11 | novoagansk
# Processing Record 3 of Set 11 | saint anthony
# Processing Record 4 of Set 11 | vanderhoof
# Processing Record 5 of Set 11 | orda
# Processing Record 6 of Set 11 | lagoa
# Processing Record 7 of Set 11 | flin flon
# Processing Record 8 of Set 11 | dillon
# Processing Record 9 of Set 11 | havoysund
# Processing Record 10 of Set 11 | nizhnevartovsk
# Processing Record 11 of Set 11 | bullhead city
# Processing Record 12 of Set 11 | kasongo-lunda
# Processing Record 13 of Set 11 | teya
# Processing Record 14 of Set 11 | pasaje
# Processing Record 15 of Set 11 | shakawe
# Processing Record 16 of Set 11 | raudeberg
# Processing Record 17 of Set 11 | tectitan
# City not found. Skipping...
# Processing Record 18 of Set 11 | bandarbeyla
# Processing Record 19 of Set 11 | vestmanna
# Processing Record 20 of Set 11 | formoso do araguaia
# City not found. Skipping...
# Processing Record 21 of Set 11 | tuam
# Processing Record 22 of Set 11 | mulege
# Processing Record 23 of Set 11 | oil city
# Processing Record 24 of Set 11 | berlevag
# Processing Record 25 of Set 11 | ocampo
# Processing Record 26 of Set 11 | mbour
# Processing Record 27 of Set 11 | hambantota
# Processing Record 28 of Set 11 | antofagasta
# Processing Record 29 of Set 11 | porto santo
# Processing Record 30 of Set 11 | xuchang
# Processing Record 31 of Set 11 | cape canaveral
# Processing Record 32 of Set 11 | valdosta
# Processing Record 33 of Set 11 | turan
# Processing Record 34 of Set 11 | naftah
# City not found. Skipping...
# Processing Record 35 of Set 11 | jucurutu
# Processing Record 36 of Set 11 | bhanvad
# Processing Record 37 of Set 11 | tsihombe
# City not found. Skipping...
# Processing Record 38 of Set 11 | kavaratti
# Processing Record 39 of Set 11 | lishu
# Processing Record 40 of Set 11 | lipin bor
# Processing Record 41 of Set 11 | praia da vitoria
# Processing Record 42 of Set 11 | ossora
# Processing Record 43 of Set 11 | dubrovnik
# Processing Record 44 of Set 11 | palmer
# Processing Record 45 of Set 11 | geraldton
# Processing Record 46 of Set 11 | belyy yar
# Processing Record 47 of Set 11 | kargasok
# Processing Record 48 of Set 11 | burnie
# Processing Record 49 of Set 11 | mirnyy
# Processing Record 50 of Set 11 | margate
# Processing Record 1 of Set 12 | itaituba
# Processing Record 2 of Set 12 | touros
# Processing Record 3 of Set 12 | camopi
# Processing Record 4 of Set 12 | tumannyy
# City not found. Skipping...
# Processing Record 5 of Set 12 | la asuncion
# Processing Record 6 of Set 12 | deputatskiy
# Processing Record 7 of Set 12 | vao
# Processing Record 8 of Set 12 | fort nelson
# Processing Record 9 of Set 12 | road town
# Processing Record 10 of Set 12 | eidsvag
# Processing Record 11 of Set 12 | plettenberg bay
# Processing Record 12 of Set 12 | aswan
# Processing Record 13 of Set 12 | fiche
# Processing Record 14 of Set 12 | san vicente
# Processing Record 15 of Set 12 | jalu
# Processing Record 16 of Set 12 | mana
# Processing Record 17 of Set 12 | imbituba
# Processing Record 18 of Set 12 | yenagoa
# Processing Record 19 of Set 12 | luwuk
# Processing Record 20 of Set 12 | zhaotong
# Processing Record 21 of Set 12 | boueni
# Processing Record 22 of Set 12 | haibowan
# City not found. Skipping...
# Processing Record 23 of Set 12 | sisimiut
# Processing Record 24 of Set 12 | kodinsk
# Processing Record 25 of Set 12 | susanville
# Processing Record 26 of Set 12 | abu jubayhah
# City not found. Skipping...
# Processing Record 27 of Set 12 | mendahara
# City not found. Skipping...
# Processing Record 28 of Set 12 | louisbourg
# City not found. Skipping...
# Processing Record 29 of Set 12 | rampura
# Processing Record 30 of Set 12 | requena
# Processing Record 31 of Set 12 | santa rosa
# Processing Record 32 of Set 12 | aksu
# Processing Record 33 of Set 12 | gazojak
# Processing Record 34 of Set 12 | port-gentil
# Processing Record 35 of Set 12 | rio branco
# Processing Record 36 of Set 12 | skalistyy
# City not found. Skipping...
# Processing Record 37 of Set 12 | hamilton
# Processing Record 38 of Set 12 | soyo
# Processing Record 39 of Set 12 | sosnovo-ozerskoye
# Processing Record 40 of Set 12 | strelka
# Processing Record 41 of Set 12 | paine
# Processing Record 42 of Set 12 | lakatoro
# Processing Record 43 of Set 12 | kulu
# Processing Record 44 of Set 12 | codrington
# Processing Record 45 of Set 12 | ambanja
# Processing Record 46 of Set 12 | zeya
# Processing Record 47 of Set 12 | beringovskiy
# Processing Record 48 of Set 12 | ancud
# Processing Record 49 of Set 12 | ialibu
# Processing Record 50 of Set 12 | fairbanks
# Processing Record 1 of Set 13 | nome
# Processing Record 2 of Set 13 | boralday
# Processing Record 3 of Set 13 | batticaloa
# Processing Record 4 of Set 13 | rodrigues alves
# Processing Record 5 of Set 13 | barbar
# City not found. Skipping...
# Processing Record 6 of Set 13 | aanekoski
# Processing Record 7 of Set 13 | abbeville
# Processing Record 8 of Set 13 | presidencia roque saenz pena
# Processing Record 9 of Set 13 | cidreira
# Processing Record 10 of Set 13 | yeppoon
# Processing Record 11 of Set 13 | rognan
# Processing Record 12 of Set 13 | okha
# Processing Record 13 of Set 13 | balakovo
# Processing Record 14 of Set 13 | kendari
# Processing Record 15 of Set 13 | grand centre
# City not found. Skipping...
# Processing Record 16 of Set 13 | opuwo
# Processing Record 17 of Set 13 | hirara
# Processing Record 18 of Set 13 | wagga wagga
# Processing Record 19 of Set 13 | hue
# Processing Record 20 of Set 13 | burlington
# Processing Record 21 of Set 13 | fano
# Processing Record 22 of Set 13 | ornskoldsvik
# Processing Record 23 of Set 13 | del rio
# Processing Record 24 of Set 13 | kolosovka
# Processing Record 25 of Set 13 | mama
# Processing Record 26 of Set 13 | andrelandia
# Processing Record 27 of Set 13 | hovd
# Processing Record 28 of Set 13 | lolua
# City not found. Skipping...
# Processing Record 29 of Set 13 | durban
# Processing Record 30 of Set 13 | sovetskiy
# Processing Record 31 of Set 13 | aklavik
# Processing Record 32 of Set 13 | firozpur jhirka
# Processing Record 33 of Set 13 | buala
# Processing Record 34 of Set 13 | roma
# Processing Record 35 of Set 13 | lasa
# Processing Record 36 of Set 13 | lahij
# Processing Record 37 of Set 13 | pietarsaari
# Processing Record 38 of Set 13 | batagay-alyta
# Processing Record 39 of Set 13 | eyl
# Processing Record 40 of Set 13 | devonport
# Processing Record 41 of Set 13 | clermont
# Processing Record 42 of Set 13 | chaupimarca
# Processing Record 43 of Set 13 | cody
# Processing Record 44 of Set 13 | zhangye
# Processing Record 45 of Set 13 | alotau
# City not found. Skipping...
# Processing Record 46 of Set 13 | atar
# Processing Record 47 of Set 13 | urbana
# Processing Record 48 of Set 13 | rosbach
# Processing Record 49 of Set 13 | karaul
# City not found. Skipping...
# Processing Record 50 of Set 13 | karratha
# Processing Record 1 of Set 14 | urdoma
# Processing Record 2 of Set 14 | vanavara
# Processing Record 3 of Set 14 | port blair
# Processing Record 4 of Set 14 | lucapa
# Processing Record 5 of Set 14 | shimoda
# Processing Record 6 of Set 14 | yaan
# Processing Record 7 of Set 14 | marawi
# Processing Record 8 of Set 14 | tete
# Processing Record 9 of Set 14 | kysyl-syr
# Processing Record 10 of Set 14 | grand gaube
# Processing Record 11 of Set 14 | newport
# Processing Record 12 of Set 14 | zabaykalsk
# Processing Record 13 of Set 14 | mwinilunga
# Processing Record 14 of Set 14 | buy
# Processing Record 15 of Set 14 | bud
# Processing Record 16 of Set 14 | pagudpud
# Processing Record 17 of Set 14 | ambon
# Processing Record 18 of Set 14 | sistranda
# Processing Record 19 of Set 14 | marsabit
# Processing Record 20 of Set 14 | san juan
# Processing Record 21 of Set 14 | okato
# Processing Record 22 of Set 14 | shieli
# Processing Record 23 of Set 14 | cururupu
# Processing Record 24 of Set 14 | ovsyanka
# Processing Record 25 of Set 14 | maniitsoq
# Processing Record 26 of Set 14 | husavik
# Processing Record 27 of Set 14 | sterlibashevo
# Processing Record 28 of Set 14 | saint-joseph
# Processing Record 29 of Set 14 | kazachinskoye
# Processing Record 30 of Set 14 | nouadhibou
# Processing Record 31 of Set 14 | sug-aksy
# City not found. Skipping...
# Processing Record 32 of Set 14 | mildura
# Processing Record 33 of Set 14 | redlands
# Processing Record 34 of Set 14 | faaborg
# Processing Record 35 of Set 14 | puerto madero
# Processing Record 36 of Set 14 | bilma
# Processing Record 37 of Set 14 | probolinggo
# Processing Record 38 of Set 14 | sarakhs
# Processing Record 39 of Set 14 | zlobin
# Processing Record 40 of Set 14 | shihezi
# Processing Record 41 of Set 14 | tommot
# Processing Record 42 of Set 14 | sao joao da barra
# Processing Record 43 of Set 14 | luanda
# Processing Record 44 of Set 14 | agadir
# Processing Record 45 of Set 14 | joshimath
# Processing Record 46 of Set 14 | jiddah
# City not found. Skipping...
# Processing Record 47 of Set 14 | san cristobal
# Processing Record 48 of Set 14 | pak phanang
# Processing Record 49 of Set 14 | duku
# Processing Record 50 of Set 14 | wangqing
# Processing Record 1 of Set 15 | buin
# Processing Record 2 of Set 15 | saint-pierre
# Processing Record 3 of Set 15 | glyadyanskoye
# Processing Record 4 of Set 15 | ormara
# Processing Record 5 of Set 15 | awjilah
# Processing Record 6 of Set 15 | aloleng
# Processing Record 7 of Set 15 | imeni poliny osipenko
# Processing Record 8 of Set 15 | solnechnyy
# Processing Record 9 of Set 15 | obo
# Processing Record 10 of Set 15 | santa maria
# Processing Record 11 of Set 15 | omsukchan
# Processing Record 12 of Set 15 | faya
# Processing Record 13 of Set 15 | guozhen
# Processing Record 14 of Set 15 | salta
# Processing Record 15 of Set 15 | goure
# Processing Record 16 of Set 15 | dukat
# Processing Record 17 of Set 15 | palmerston
# Processing Record 18 of Set 15 | ban dung
# Processing Record 19 of Set 15 | kondinskoye
# Processing Record 20 of Set 15 | biharamulo
# Processing Record 21 of Set 15 | belaya gora
# Processing Record 22 of Set 15 | paamiut
# Processing Record 23 of Set 15 | norwich
# Processing Record 24 of Set 15 | qrendi
# Processing Record 25 of Set 15 | sliema
# Processing Record 26 of Set 15 | banmo
# City not found. Skipping...
# Processing Record 27 of Set 15 | quelimane
# Processing Record 28 of Set 15 | makung
# City not found. Skipping...
# Processing Record 29 of Set 15 | krutikha
# Processing Record 30 of Set 15 | sidi ali
# Processing Record 31 of Set 15 | leningradskiy
# Processing Record 32 of Set 15 | grindavik
# Processing Record 33 of Set 15 | kutum
# Processing Record 34 of Set 15 | tateyama
# Processing Record 35 of Set 15 | brae
# Processing Record 36 of Set 15 | turayf
# Processing Record 37 of Set 15 | eisiskes
# Processing Record 38 of Set 15 | pemangkat
# Processing Record 39 of Set 15 | awbari
# Processing Record 40 of Set 15 | rosario
# Processing Record 41 of Set 15 | vung tau
# Processing Record 42 of Set 15 | biskamzha
# Processing Record 43 of Set 15 | nurota
# Processing Record 44 of Set 15 | oituz
# Processing Record 45 of Set 15 | kelc
# Processing Record 46 of Set 15 | soderhamn
# Processing Record 47 of Set 15 | suntar
# Processing Record 48 of Set 15 | lubana
# Processing Record 49 of Set 15 | linqing
# Processing Record 50 of Set 15 | scottsburgh
# City not found. Skipping...
# Processing Record 1 of Set 16 | champerico
# Processing Record 2 of Set 16 | qaqortoq
# Processing Record 3 of Set 16 | halifax
# Processing Record 4 of Set 16 | rocha
# Processing Record 5 of Set 16 | burns lake
# Processing Record 6 of Set 16 | neuquen
# Processing Record 7 of Set 16 | orcopampa
# Processing Record 8 of Set 16 | buenaventura
# Processing Record 9 of Set 16 | avera
# Processing Record 10 of Set 16 | nuuk
# Processing Record 11 of Set 16 | ouesso
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Display the weather DF
weather_df = pd.DataFrame(city_data)
weather_df.head(3)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Hobart      AU -42.8794  147.3294     49.86        83          40
# 1       Qinzhou      CN  21.9500  108.6167     80.96        77          78
# 2  Ponta Do Sol      PT  32.6667  -17.1000     79.43        84          39
#
#    Wind Speed Current Description
# 0       11.50    scattered clouds
# 1        5.32       broken clouds
# 2        3.78          light rain

# %%
# Export the Weather DF into a .csv file
weather_df.to_csv('Weather_Database.csv')
